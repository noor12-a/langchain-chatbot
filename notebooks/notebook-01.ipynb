# %%
from langchain_ollama import ChatOllama

# %%
llm= ChatOllama(
    model="glm-5:cloud",
    temperature=0.7
)

# %%
response = llm.invoke("what is RAG")

# %%
print(response.content)
# Out:
# **RAG** stands for **Retrieval-Augmented Generation**. It is a technique used in artificial intelligence to improve the accuracy and reliability of Large Language Models (LLMs) by giving them access to external, up-to-date data.
#
# Here is a simple breakdown of how it works and why it matters:
#
# ### The Problem with Standard LLMs
# Models like ChatGPT or Llama are trained on a massive amount of data, but their knowledge is "frozen" at the time training ended. They don't know about events that happened yesterday, and they often lack specific knowledge about private company data. This leads to **hallucinations**—where the model confidently makes things up.
#
# ### How RAG Solves This
# RAG acts like an open-book exam. Instead of relying only on what it memorized during training (the closed-book exam), the AI can look up relevant information before answering.
#
# The process involves three main steps:
#
# 1.  **Retrieval:** When a user asks a question, the system searches an external data source (like a company database, PDF files, or the internet) to find documents or chunks of text that are relevant to the query.
# 2.  **Augmentation:** The system appends (adds) this retrieved information to the user's original prompt. This provides the LLM with the specific context it needs.
# 3.  **Generation:** The LLM processes the prompt and the new data together to generate a precise answer, citing the retrieved information rather than relying on its internal memory.
#
# ### Key Benefits
# *   **Accuracy:** It significantly reduces hallucinations because the model bases its answer on factual data provided to it.
# *   **Up-to-date Information:** You can update the external database instantly without retraining the model.
# *   **Data Privacy:** Companies can use RAG to let AI chat with their private internal documents without needing to feed that sensitive data into the public training set of a model like GPT-4.

# %%
if 'response' in locals():
	type(response)
else:
	print("'response' is not defined. Please run the previous cells first.")

# %%
response.response_metadata
# Out:
# {'model': 'glm-5:cloud',
#  'created_at': '2026-03-04T09:32:50.969630731Z',
#  'done': True,
#  'done_reason': 'stop',
#  'total_duration': 15184120432,
#  'load_duration': None,
#  'prompt_eval_count': 9,
#  'prompt_eval_duration': None,
#  'eval_count': 694,
#  'eval_duration': None,
#  'logprobs': None,
#  'model_name': 'glm-5:cloud',
#  'model_provider': 'ollama'}

# %%
response.content
# Out:
# '**RAG** stands for **Retrieval-Augmented Generation**. It is a technique used in artificial intelligence to improve the accuracy and reliability of Large Language Models (LLMs) by giving them access to external, up-to-date data.\n\nHere is a simple breakdown of how it works and why it matters:\n\n### The Problem with Standard LLMs\nModels like ChatGPT or Llama are trained on a massive amount of data, but their knowledge is "frozen" at the time training ended. They don\'t know about events that happened yesterday, and they often lack specific knowledge about private company data. This leads to **hallucinations**—where the model confidently makes things up.\n\n### How RAG Solves This\nRAG acts like an open-book exam. Instead of relying only on what it memorized during training (the closed-book exam), the AI can look up relevant information before answering.\n\nThe process involves three main steps:\n\n1.  **Retrieval:** When a user asks a question, the system searches an external data source (like a company database, PDF files, or the internet) to find documents or chunks of text that are relevant to the query.\n2.  **Augmentation:** The system appends (adds) this retrieved information to the user\'s original prompt. This provides the LLM with the specific context it needs.\n3.  **Generation:** The LLM processes the prompt and the new data together to generate a precise answer, citing the retrieved information rather than relying on its internal memory.\n\n### Key Benefits\n*   **Accuracy:** It significantly reduces hallucinations because the model bases its answer on factual data provided to it.\n*   **Up-to-date Information:** You can update the external database instantly without retraining the model.\n*   **Data Privacy:** Companies can use RAG to let AI chat with their private internal documents without needing to feed that sensitive data into the public training set of a model like GPT-4.'
